# %% [markdown]
# # **Implement** a Du Bois Choropleth Map with **Python**:
#
# <div>
# <img src="https://github.com/ajstarks/dubois-data-portraits/blob/master/plate02/original-plate-02.jpg?raw=true" width="700" />
# </div>
#
# <b>Plate 02</b>

# %% [markdown]
# ### This interactive exercise is inspired by the annual #DuBoisChallenge
#
# The #DuBoisChallenge is a call to scientists, students, and community members to recreate, adapt, and share on social media the data visualzations created by W.E.B. Du Bois and his collaborators in 1900. Before doing the interactive exercise, please read this article about the [Du Bois Challenge](https://nightingaledvs.com/the-dubois-challenge/) You can find the latest Du Bois visualizations by searching for the [#DuBoisChallenge2025](https://github.com/ajstarks/dubois-data-portraits/tree/master/challenge/2025) hash tag on social media (Twitter, Bluesky, Insta etc). And you can even use the hashtag to share your own recreations.
#
# ### In this interactive excercise, you will:
# 1. Learn how to create a variation of a **choropleth map**.
# 2. Learn and modify code in the programming language **Python**.
# 3. Learn how to write spatial and statistical code to:
#     * create visualizations that consistently and accurately represent your data
#     * create a transparent record of exactly how you visualized something
#     * make it easy for you or others to recreate or modify your visualization
# 4. Your instructor may also ask you answer questions and submit screenshots as you go in a parallel Catcourses (or other Canvas system) as you go.
#
# ### You will learn how to use the *Python* programming language by creating a choropleth map:
# 1. You will adapt Du Bois' visualization of the Black population across US states in 1900. The map was presented by Du Bois at the 1900 Paris World Exposition of the latest scientific research and technology at the time. The exposition was the 1900 equivalent of today's social media, attended by 48 million people from around the world.
# 2. Du Bois told a larger data story by combining the above map with other visualizations to explain the adversities and accomplishments of Black Americans who lived overwhelmingly in the US South. The first visual in the 1900 exhibition is a map of world and lines showing the transatlantic slave trade that led to Black clustering in southern states, including Georgia.
#
# <div>
# <img src="https://github.com/ajstarks/dubois-data-portraits/blob/master/plate01/original-plate-01.jpg?raw=true" width="700"/>
# </div>
# <b>Plate 01</b>

# %% [markdown]
# ### 1. How to use this interactive **Jupyter Notebook**
#
# If you know how to excute Python on your own computer with another code editor like Pycharm or VS code, you can copy, paste, and edit code there. If you have Jupyter Lab, you can also download this Notebook to use it on your own computer. You can download the Notebook or view a non-interactive version of this Notebook by clicking here.
#
# Grey cells in the *Notebook* like the one below are code cells where you will write and edit **Python** Code. To try it out:
#
# 1. Click your cursor on the grey cell below. After you click on it, it will change to white to indicate you are editing it.
# 2. After you click on the cell below and it turns white. Type ```2+2``` to use Python as a calculator.
# 3. After typing ```2+2```, click the <span class="play-button">&#9654;</span> play button at the top of this page.

# %% [markdown]
# ### 2. Keeping track of your work and using **Python** outside of this notebook.
#
# If you leave this Notebook idle or close/re-open it, your work will not be saved in the Notebook. But you can export an HTML file showing your work at any time. You can then open and browse the HTML file in any web browser.
#
# And after completing the Notebook exercises, you can export a final HTML file to submit for any course assignments using this Notebook.
#
# To export the *Notebook*, click the **File** dropdown above, select **Export File As** and then select **HTML** as shown here:
#
# <div>
# <img src="https://github.com/HigherEdData/Du-Bois-STEM/blob/main/readings-images/htmlexport.jpg?raw=true" width="500" />
# </div>

# %% [markdown]
# ### 3. Getting hints and answers.
#
# Sometimes, the code cells will already have code in them that you will be asked to edit or run by clicking the play button. In the process, you can click on <span class="play-button">&#9654;</span> dropdown buttons like the ones below to get hints and answers. For example:
#
# 1. Click on the cell below with ```3+3=``` and click the play triangle above. You should get an error message highlighted in pink saying "SyntaxError: cannot assign to expression". To complete this activity, you'll want to get each code cell to run without a pink error message.
# 2. Based on the ```2+2``` code you tried above, try to edit the 3+3= code to get it to report the sum of 3+3 without the error message. For a hint, click the first <span class="play-button">&#9654;</span> button below.

# %% [markdown]
# <details> <summary>Click this triangle for a hint.</summary>
#
# Try deleting the ```=``` sign in the cell and click play again. If that doesn't work, click the next triangle below for the answer.
#
# </details>
#
# <details> <summary>Click this triangle for the answer.</summary>
#
# **Answer:** Delete all the text in the cell below and write or paste this answer in the cell: ```3+3``` before clicking play again.
#
# </details>

# %%
3+3=

# %%
3+3
# Out:
# 6

# %% [markdown]
# ### 4. Reading and writing comments that explain your code
#
# In code cells, we can write **comment** text that explains our code. We put a ```#```  before **comment** text to tell Python that the text is not code it should execute. Any text after a ```#``` on a given line will be treated as a **comment**. In Jupyter, comment text after a ```#``` will be displayed in a dark turquois color. To see how this works, try the following below:
#
# 1. Try to run the code below. You should get an error message because the comment text ```This is code that adds 2+2``` is not Python code and doesn't have a ```#``` sign in front of it.
# 2. Add a #  sign before ```This is code that adds 2+2```. This should change the color of the text to turquois like the text after the 2+2 where there is already a ```#``` sign.
# 3. Click the <span class="play-button">&#9654;</span> at the top of the notebook and the code should run and output **4** below.

# %% [markdown]
# <details> <summary><strong>Hints:</strong></summary>
#
# **Answer:** ```#This is code that adds 2+2```
#
# </details>

# %%
This is code that adds 2+2

print(2+2) # the result of 2 +2 should be 4

# %%
#This is code that adds 2+2

print(2+2) # the result of 2 +2 should be 4
# Out:
# 4

# %% [markdown]
# ### 5. Importing libraries
# In **Python**, users can import libraries which a range of tools we can call on for our code. These are the most common libraries pertaining to statisitcs, mapping, and visualizations:
# * **pandas** is a library with statistical capacities including data management.
# * **geopandas** is the library has geospatial abilities.
# * **matplotlib** is a library with data visualizations, we will be using pyplots.
# * **mapclassify** is a library with many spatial map classification options.
#
# In today's workbook, we will rely on these libraries.

# %% [markdown]
# Once you have the appropriate **Python** libraries, you call on these libraries at the beginning of your **Python** code script. There are three ways to call libraries:
#
# 1. Call on the library the basic way: ```import library_name```
# 2. Call on the library and add aliases to call it easily: ```import library_name as lib```
# 3. Call on specifics functions from library: ```import library.function as fun```

# %%
#importing necessary libaries
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import mapclassify

# %%
#importing necessary libaries
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import mapclassify

# %% [markdown]
# ### 6. Tabular Data and Reading Du Bois' data into an **Pandas** Data Frame
#
# Recreating Du Bois portraits using modern data allows us to apply important spatial analysis techniques such as rates/proportions, data classification, and visual accessibility. This exercise draws on *Plate 02* as a learning tool to creating choropleth maps.
#
# In order to make data visuals, we first need data organized in a table. Tabular data is commonly stored in an excel file (.xls) or comma-separated vector file (.csv). For this exercise, we are using Black population counts by US state from the 2020 US census. They are stored in a **data2020.csv** file.
#
# To import our **data2020.csv**, we will use functions from **Pandas (pd)**, the the most common library for data management and analysis in **Python**. In **Python** data tables are commonly referred to as **data frames.** So our first step is to import our **.csv** data into a Python **data frame**.
#
# We will import the **data2020.csv** from the **Du Bois STEM** github website. So we first create a Python object with the url where the **data2020.csv** data file is located using this code:
#
# ```csvurl="https://github.com/HigherEdData/Du-Bois-STEM/raw/refs/heads/main/data/d_popmap.csv"```
#
# Then we "read" the **data2020.csv** data into Python and place it in a **data frame** named **df**. We can do this by using the **pandas** function ```read_csv```. We tell Python that this function is from the **pandas** library by writing **pd.** immediately before the function. And we tell the ```read_csv``` function to read the data file in from our url location by placing "csvurl" in parentheses after the function as follows:
#
# ```df = pd.read_csv(csvurl)```
#
# In the code cell below, edit the code to import the **data2020.csv** data and place it in a **data frame** named **df**. We can do this by using the **pandas** function ```read_csv```. We tell Python that this function is from the **pandas** library by writing **pd.** immediately before the function as follows:
#
# ```df = pd.read_csv```
#
# Finally, we check to see if the data was successfully read into the **df** data frame by writing the ```head()``` function after ``df.``. This displays the top 5 rows of the data which is known as the "head" fo the data:
#
# ```df.head()```
#
# Fill in the blank of the cell below to tell **Python** that the read function is from the pd pandas library. Then run the code cell to make sure it works.

# %% [markdown]
# <details> <summary><strong>**Answer:** </strong></summary>
#
# ```df = pd.read_csv(csvurl)```
#
# </details>

# %%
csvurl="https://github.com/HigherEdData/Du-Bois-STEM/raw/refs/heads/main/data/d_popmap.csv"
df = __.read_csv(csvurl)
df.head()

# %%
csvurl="https://github.com/HigherEdData/Du-Bois-STEM/raw/refs/heads/main/data/d_popmap.csv"
df = pd.read_csv(csvurl)
df.head()
# Out:
#   GISJOIN    STATENAM    totpop   blkpop         blkpop_cat
# 0    G010     Alabama   5024279  1296162   750,000 AND OVER
# 1    G020      Alaska    733391    21898    10,000 - 25,000
# 2    G040     Arizona   7151502   339150  300,000 - 500,000
# 3    G050    Arkansas   3011524   453783  300,000 - 500,000
# 4    G060  California  39538223  2237044   750,000 AND OVER

# %% [markdown]
# ### 7. Spatial Data and Using **GeoPandas** to read, plot, and edit a shapefile
#
# To create a statistical map, we also need geospatial data that contains the shape of the spatial units in the map (in our case the borders of states). These data are commonly stored in a (.shp) shape file. Free historical shapefiles are available at [NHGIS]("https://www.nhgis.org/").
#
# We have stored a NHGIS geospatial data for US states in 2020 in a us_state_2020_reduced.shp file at the Du Bois STEM github site. Using the same code syntax explained above, we tell Python the url where the .shp is stored:
#
# ```shpurl="https://github.com/HigherEdData/Du-Bois-STEM/raw/refs/heads/main/data/us_state_2020/us_state_2020_reduced.shp"```
#
# To import and manage geospatial data like .shp files, we use the **Geopandas (gpd)** library. Using the same syntax explained for **Pandas (pd)** above, we can use **Geopandas (gpd)** to read the **.shp** map shape file into a **geo dataframe (gdf)** as follows:
#
# ```gdf = gpd.read_file(shpurl)```
#
# Just as we displayed the head of the df dataframe with state Black population data, we can display the head of the **gdf** geodataframe with the code ```gdf.head()```.
#
# Fill in the blank in the code cell below tell Python that the ```read_file``` function to read in the .shp data is from the **geopandas (gpd)** library.
#
# Note the geometry column provides the series of x, y coordinates needed to plot the outline of each state.

# %% [markdown]
# <details> <summary><strong>**Answer:** </strong></summary>
#
# ```gdf = gpd.read_file(shpurl)```
#
# </details>

# %%
shpurl="https://github.com/HigherEdData/Du-Bois-STEM/raw/refs/heads/main/data/us_state_2020/us_state_2020_reduced.shp"
gdf = ___.read_file(shpurl)
gdf.head()

# %%
shpurl="https://github.com/HigherEdData/Du-Bois-STEM/raw/refs/heads/main/data/us_state_2020/us_state_2020_reduced.shp"
gdf = gpd.read_file(shpurl)
gdf.head()
# Out:
#      STATENAM                                           geometry
# 0     Alabama  MULTIPOLYGON (((763205.386 -783799.782, 763007...
# 1     Arizona  POLYGON ((-1581748.321 94658.552, -1382280.225...
# 2    Arkansas  POLYGON ((559472.704 -149504.267, 561049.286 -...
# 3  California  MULTIPOLYGON (((-1959193.572 -309021.425, -195...
# 4    Colorado  POLYGON ((-671177.633 420817.406, -504621.167 ...

# %% [markdown]
# ### 8. Plotting geospatial data
#
# Once a geospatial dataframe is loaded, use the ```gpd.plot()``` to visually examine our shapefile.
#
# ```gdf.plot()```
#
# Fill in the blank below to tell Python to use the ``plot`` function to plot our **gdf** geo dataframe.
#
# This will display the outline of all states in our data, but without yet color coding states for their Black population size.

# %% [markdown]
# <details> <summary><strong>**Answer:** </strong></summary>
#
# ```gdf.plot()```
#
# </details>

# %%
___.plot()

# %%
gdf.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### 9. Merging tabular data with the shapefile
# Often times, we need to link a **dataframe (df)** (such as our state Black population data) to a **geo dataframe (gdf)** (such as our US state map shape data).
#
# We can use the ``.merge`` function from **GeoPandas** to do this. We do this by writing the **gdf** geo dataframe name before the ```.merge``` function. Then within parenthes for the function, we write the **df** data frame name. After a comma, we tell Python to merge the data from both the **geo dataframe (gdf)** and the **dataframe (df)** into a new **gdf_merged** geo dataframe:
#
# ```gdf_merged = gdf.merge(df, on='common_variable')```
#
# In our case, the common variable is ```STATENAM``` which contains the name of each state.
#
# Fill in the blank below to tell Python to merge the geo dataframe and the dataframe on their common ``STATENAM`` variable.
#
# Displaying the head of the new **gdf_merged** data frame will now show the Black population and the geometry data in a single table together.

# %% [markdown]
# <details> <summary><strong>**Answer:** </strong></summary>
#
# ```gdf_merged = gdf.merge(df, on='STATENAM')```
#
# </details>

# %%
gdf_merged = gdf.merge(df, on='_______')
gdf_merged.head()

# %%
#Step c: Merge the dataframe with the shapefile using STATENAM
gdf_merged = gdf.merge(df, on='STATENAM')
gdf_merged.head()
# Out:
#      STATENAM                                           geometry GISJOIN  \
# 0     Alabama  MULTIPOLYGON (((763205.386 -783799.782, 763007...    G010
# 1     Arizona  POLYGON ((-1581748.321 94658.552, -1382280.225...    G040
# 2    Arkansas  POLYGON ((559472.704 -149504.267, 561049.286 -...    G050
# 3  California  MULTIPOLYGON (((-1959193.572 -309021.425, -195...    G060
# 4    Colorado  POLYGON ((-671177.633 420817.406, -504621.167 ...    G080
#
#      totpop   blkpop         blkpop_cat
# 0   5024279  1296162   750,000 AND OVER
# 1   7151502   339150  300,000 - 500,000
# 2   3011524   453783  300,000 - 500,000
# 3  39538223  2237044   750,000 AND OVER
# 4   5773714   234828  200,000 - 300,000

# %% [markdown]
# ### 10.1 Understanding Choropleth Maps
# **Choropleth maps** are a popular way to visualize spatial data. They can be used to show data across geographic units by  coloring geographic units based on a color that corresponds to a value. For example, the count of a species across zip codes or the average household income by census tract. A common choropleth map will shade higher numbers in darker colors and lower numbers are shaded in ligther colors.
#
# The word choropleth comes from the Greek choro, meaning "region." These maps are designed to show data at the regional level, so they’re best used with data tied to specific areal units—think polygons on a map, like the shape of Merced County or the state of California.
#
# Because choropleth maps aggregate data by geographic unit, we often need to group our data into a smaller number of categories, or classes. This step is called *classification*. Each class gets its own color, and all regions that fall within the same class are shaded the same. This helps simplify complex data so that it’s easier to interpret visually. In the **Du Bois Statistical Map** the data we are classifying is the **Black population count for each state.** This data is in our data frame in a variable named ```blkpop```.
#
# While modern mapping software allows us to create unclassed maps—where every unique value gets its own symbol or color—there are still good reasons to use classed choropleths. Grouping data reduces visual clutter and helps map readers focus on patterns rather than being overwhelmed by too much detail. It’s a balance between simplification and meaning.
#
# According Dr. Erin Hestir, there are three key steps to creating effective choropleth maps:
#
# 1. **How many classes should I use?** Too many, and the map gets confusing; too few, and important detail is lost.
#
# 2. **What classification method should I apply?** Options include equal interval, quantiles, natural breaks, and more—each tells a slightly different story.
#
# 3. **How should I symbolize the data?** Thoughtful color choice matters. The color scheme needs to reflect the underlying pattern without misleading the viewer.
#
# In sum, choropleth maps help us communicate non-spatial information—like health outcomes or economic indicators—through the spatial lens of a map. They sit at the intersection of data science, geography, and design, offering a powerful way to explore and share insights about our world.
#
# Throughout this workbook, we will review these steps. We hope by the end of the session, you will discover why choropleth maps are an effective data visualization technique.

# %% [markdown]
# ### 10.2 Create **choropleth map** in **GeoPandas** by choosing a class variable.
#
# To create a choropleth map with **GeoPandas**, we use the same code we used previously to plot our geo dataframe, but we add two specifications to the function within the parentheses:
# 1. We add a variable name '''blkpop''' (Black population) for which we will classify and color code its data: ```column='blkpop```
# 2. Following a comma after the variable name, we specify ```legend = True```. This tells python to add a legend to the map which tells us what population size is indicated by different colors.
#
# Recall that our merged geo dataframe is named ```gdf_merged```. So that is the dataframe we will plot.
#
# **Edit and execute the code below to:**
# 1. fill in the blank with the ```blkpop``` variable name.
# 2. fill in the blank to tell **Python** to include a legend.
#
# The numbers next to the color bar signify the millions of Black state residents that correspond to each color.

# %% [markdown]
# <details> <summary><strong>**Answer:** </strong></summary>
#
# ```gdf_merged.plot(column='blkpop', legend = True)```
#
# </details>

# %%
gdf_merged.plot(column='______', legend = ____)

# %%
gdf_merged.plot(column='blkpop', legend = True)
# Out:
# <Axes: >

# %% [markdown]
# ## 11.1 Data Classification
#
# Rather than use a continuously shaded color bar, Du Bois used separate colors for separate categories in his original map. This can sometimes help to more clearly see geographic patterns in our data.
#
# Choosing separate categories for plotting is a process known as **data classification**. The data classification process assigns attribute values to a limited number of meaningful groups, or classes. Classification simplifies continuous or complex datasets into interpretable patterns, making it easier to compare and communicate information through maps.
#
# In the context of cartography and spatial analysis, classification is particularly important for **quantitative attributes** (such as population sizes or income), where values exist on ordinal, interval, or ratio scales and can be ordered. Grouping these values into classes helps reduce visual complexity while still preserving important trends and differences. This is not only useful for single-map interpretation, but also for **temporal or spatial comparison**, such as examining changes in Black population density across centuries or between regions.
#
# Data classification also has implications beyond visual clarity. The choice of classification method directly shapes how the user perceives the underlying data. For example, classifying continuous population values into five categories can reveal regional trends that might be obscured in an unclassed map. Similarly, choosing one classification scheme over another—like quantiles versus natural breaks—can highlight or mask certain spatial patterns.
#
# Ultimately, the goal of classification is to **enhance map readability while retaining analytical integrity.** As you’ll see in this section, selecting the number of classes and how data is grouped isn't arbitrary—it’s a crucial design decision that affects both the **accuracy** and **interpretability** of your map.

# %% [markdown]
# ## 11.2 Choosing the Number of Classes
#
# The number of classes you select should be informed by the spatial distribution of the data and the audience's ability to interpret the map. Too many classes can overwhelm the viewer, while too few can oversimplify the story the data is telling.
#
# - **Too many classes** (e.g., 9 or more) can clutter the map, make colors harder to distinguish, and demand greater cognitive effort from the reader.
#
# - **Too few classes** (e.g., 2 or 3) can obscure important variation and may group very different values into the same category.
#
# *Note: Data quality or uncertainty should not influence your choice of class number—classification is about visualization, not about error correction.*
#
# The code cell below generates 3 different versions of our map that demonstrate the visual impact of choosing different numbers of classes on a choropleth map. If you want to view the code generating the 3 maps, click on the **...** in the code cell.
#
# **What different patterns do you see across the maps with different numbers of classes?**

# %%
# Plot maps with different numbers of classes
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# 3 Classes
gdf_merged.plot(
    column='blkpop',
    scheme='Quantiles',
    k=3,
    legend=True,
    ax=axs[0],
    legend_kwds={},
)
axs[0].set_title("Three Classes")
axs[0].axis('off')

# 5 Classes
gdf_merged.plot(
    column='blkpop',
    scheme='Quantiles',
    k=5,
    legend=True,
    ax=axs[1],
    legend_kwds={},
)
axs[1].set_title("Five Classes")
axs[1].axis('off')

# 9 Classes
gdf_merged.plot(
    column='blkpop',
    scheme='Quantiles',
    k=9,
    legend=True,
    ax=axs[2],
    legend_kwds={},
)
axs[2].set_title("Nine Classes")
axs[2].axis('off')

plt.tight_layout()
plt.suptitle("Impact of Class Number on Choropleth Map Readability", fontsize=16, y=1.05)
plt.show()

# %% [markdown]
# ## 12.1 Common Data Classification Methods
#
# Once you decide to classify your data, the next important step is choosing a **classification method.** Each method follows a different logic for dividing the data into classes, and the method you choose can significantly influence how patterns are perceived on the map. Below are some of the most commonly used approaches:
#
# 1. **Equal Interval**
# This method divides the range of values into **equal-sized intervals.** Each class spans the same numerical distance, regardless of how the data are distributed.
#
#   - Best for: Uniformly distributed data
#
#   - Drawback: Can obscure meaningful variation in skewed data
#
# 2. **Quantiles**
# Quantiles divide the dataset so that each class contains an **equal number of features** (e.g., states or counties).
#
#   - Best for: Highlighting relative ranking or comparison
#
#   - Drawback: Class breaks may fall between very different values
#
# 3. **Natural Breaks (Jenks)**
# This method identifies natural groupings and gaps in the data using statistical optimization. It minimizes variance within classes and maximizes variance between them.
#
#   - Best for: Skewed or clustered data
#
#   - Drawback: Classes may be unevenly populated
#
# 4. **Standard Deviation**
# Class breaks are based on how far values deviate from the mean. This is useful when comparing values to an average or identifying outliers.
#
#   - Best for: Normally distributed data or emphasizing deviation
#
#   - Drawback: Not intuitive for general audiences
#
# 5. **Manual Classification**
# You choose the class breaks yourself based on domain knowledge or meaningful thresholds.
#
#   - Best for: Custom comparisons or policy-relevant thresholds
#
#   - Drawback: Can introduce subjectivity or bias
#
# Each method reveals different patterns in the same dataset. It's important to experiment and think critically about which classification best supports your map’s purpose. In the next section, you'll learn how to apply these classification methods in Python using the **mapclassify** library.
#
# Code in the cell below generates versions of our map using the 4 methods other than manual classification. If you want to view the code generating the 4 maps, click on the ... in the code cell.

# %%
# Define classification methods to test
schemes = {
    "Equal Interval": mapclassify.EqualInterval,
    "Quantiles": mapclassify.Quantiles,
    "Natural Breaks (Jenks)": mapclassify.NaturalBreaks,
    "Standard Deviation": mapclassify.StdMean
}

# Set up plot
fig, axs = plt.subplots(2, 2, figsize=(14, 10))
axs = axs.flatten()

# Plot each classification method
for i, (name, classifier) in enumerate(schemes.items()):
    # Use the correct string names for the schemes
    scheme_name = ""
    if name == "Equal Interval":
        scheme_name = "equalinterval"
    elif name == "Quantiles":
        scheme_name = "quantiles"
    elif name == "Natural Breaks (Jenks)":
        scheme_name = "naturalbreaks"
    elif name == "Standard Deviation":
        scheme_name = "stdmean"

    gdf_merged.plot(
        column='blkpop',
        scheme=scheme_name,
        classification_kwds={'k': 5} if name != "Standard Deviation" else {},
        legend=True,
        ax=axs[i]
    )
    axs[i].set_title(name)
    axs[i].axis('off')

plt.tight_layout()
plt.suptitle("Choropleth Comparison Using Different Classification Methods", fontsize=16, y=1.03)
plt.show()
# Out:
# C:\Users\cam\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# ## 12.2 Specifying Quantile Data Classification
#
# Given the general practices of data classifications, we will now recreate a choropleth map. The original plate had 10 classes, but here we want to simplify to five classes. We will use quantiles to highlight the relative comparison among states.
#
# To do this yourself, fill in the blank to tell mapclassify you want to use the **quantiles** scheme ```scheme='quantiles'``` for classification. And fill in the blank to tell mappclasify to set k=5 ```'k':5``` for the number of classifications you want.

# %% [markdown]
# <details> <summary><strong>**Answer:** </strong></summary>
#
# ```gdf_merged.plot(column='blkpop',```
#
# ```        scheme='quantiles',```
#
# ```        classification_kwds={'k': 5},```
#
# ```        legend=True,```
#
# ```        )```
#
# </details>

# %%
gdf_merged.plot(column='blkpop',
        scheme='_______',
        classification_kwds={'k': _},
        legend=True,
        )

# %%
gdf_merged.plot(column='blkpop',
        scheme='quantiles',
        classification_kwds={'k': 5},
        legend=True,
        )
# Out:
# <Axes: >

# %% [markdown]
# ## 13. Putting it all together in the Du Bois style
#
# Finally, we can put all of our code together to generate a map figure from scratch. We'll also add code reference Du Bois' original figure and format our figure to look similar to Du Bois'.
#
# To do this, we:
# 1. Add lines 1-14 of code we used earlier to import our libraries and merge our data so that this code block can work if you haven't already run that code.
# 2. Add lines 16-18 of code to use the **subplots** function of the **matplot lib** library to set up the overall figure (**fig**)to contain an **ax** subplot object that will contain our map (ax is short for the x and y axes of plot). This code also sets the size and background color (**facecolor**) of the plot.
# 3. Add the 21 to 32 expanding on the 5 lines of code we just wrote above for the **gdf_merged.plot** function to create the graph. The additional lines of code place the plot within the **ax** object of our figure and format the legend.
# 4. Add lines 35-37 of the code set the map size to match the overall figure size and remove the x, y axis coordinate lines and labels.
# 5. Add lines 39-42 to add titles to the figure.
#
# To customize the figure and execute the code, fill in the blanks on line 26 and line 43. Can you customize the color choices or other design elements that communicate something about the meaning of your analysis?
# * On line 26, try filling in the blank with different colormap options. Options include Greys, Reds, Blues, Greens, viridis, and plasma. Choose the color you like the best.
# * On line 43, fill in the blank with your name to show that you edited this code to adapt Du Bois' figure with 2020 data!
# * Try to customize one other aspect of the figure (background color, text color, embedding a photograph or another image) by using code you already know, or by copying and pasting the code below into ChatGPT and asking it how to make the change.

# %%
#importing necessary libaries
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import mapclassify

#import and merge dataframe and geodataframe
csvurl="https://github.com/HigherEdData/Du-Bois-STEM/raw/refs/heads/main/data/d_popmap.csv"
df = pd.read_csv(csvurl)

shpurl="https://github.com/HigherEdData/Du-Bois-STEM/raw/refs/heads/main/data/us_state_2020/us_state_2020_reduced.shp"
gdf = gpd.read_file(shpurl)
gdf_merged = gdf.merge(df, on='STATENAM')

fig, ax = plt.subplots(
    figsize=(11,14),         
    facecolor='antiquewhite'
)

gdf_merged.plot(column='blkpop',
        scheme='quantiles',
        classification_kwds={'k': 5},
        legend=True,
        ax=ax,
        cmap='Greys',          # set colormap options here
        legend_kwds={
        "loc": "lower center",
        "bbox_to_anchor": (0.5, 0.05),
        "title": "Black population range",   # set title here
        "title_fontsize": 20,                # title size
        "fontsize": 20,                      # label size
        "frameon": False                     # remove box
            })

ax.set_ylim(-3000000, 2500000) # set map dimensions to match figure size
plt.tight_layout() # requires plot to adhere to figure dimensions
ax.set_axis_off() # removes 

ax.set_title(r"RELATIVE BLACK POPULATION OF THE STATES OF THE"
    "\n" "UNITED STATES BY QUINTILES IN 2020"
    "\n\n" "Adapted from Du Bois' Plate 2 for the 1900 Paris World Expo"
    "\n\n" "Adapted by ____________", y=.81, fontsize=20)

# %%
#importing necessary libaries
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import mapclassify

#import and merge dataframe and geodataframe
csvurl="https://github.com/HigherEdData/Du-Bois-STEM/raw/refs/heads/main/data/d_popmap.csv"
df = pd.read_csv(csvurl)

shpurl="https://github.com/HigherEdData/Du-Bois-STEM/raw/refs/heads/main/data/us_state_2020/us_state_2020_reduced.shp"
gdf = gpd.read_file(shpurl)
gdf_merged = gdf.merge(df, on='STATENAM')

fig, ax = plt.subplots(
    figsize=(11,14),         
    facecolor='antiquewhite'
)

gdf_merged.plot(column='blkpop',
        scheme='quantiles',
        classification_kwds={'k': 5},
        legend=True,
        ax=ax,
        cmap='Greys',          # set colormap options here
        legend_kwds={
        "loc": "lower center",
        "bbox_to_anchor": (0.5, 0.05),
        "title": "Black population range",   # set title here
        "title_fontsize": 20,                # title size
        "fontsize": 20,                      # label size
        "frameon": False                     # remove box
            })

ax.set_ylim(-3000000, 2500000) # set map dimensions to match figure size
plt.tight_layout() # requires plot to adhere to figure dimensions
ax.set_axis_off() # removes 

ax.set_title(r"RELATIVE BLACK POPULATION OF THE STATES OF THE"
    "\n" "UNITED STATES BY QUINTILES IN 2020"
    "\n\n" "Adapted from Du Bois' Plate 2 for the 1900 Paris World Expo"
    "\n\n" "Adapted by ____________", y=.81, fontsize=20)
# Out:
# Text(0.5, 0.81, "RELATIVE BLACK POPULATION OF THE STATES OF THE\nUNITED STATES BY QUINTILES IN 2020\n\nAdapted from Du Bois' Plate 2 for the 1900 Paris World Expo\n\nAdapted by ____________")

# %% [markdown]
# ## 14. Interpreting and contextualizing your map with a data story
#
# How does your 2020 Black population map differ the 1900 Black population map presented at the top of this Notebook? Which 5 states have the most Black residents? How does this compare to the 5 states with the most Black residents in Du Bois' 1900 graph?
#
# Du Bois developed a data story to contextualize his 1900 map of the Black US population by state by presenting it with another map, "The Routes of the African Slave Trade" (also shown at the top of this Notebook).
#
# Go to the Phillips Collection website [here](https://lawrencemigration.phillipscollection.org/culture/migration-map) to view a visualization of the Great Migration. How could you combine your map with this map to tell a data story explaining your findings?

# %% [markdown]
# ## 15. Export a final HTML file of your Notebook
#
# Now that you're done, remember to export a final HTML file showing your work and displaying your name within the visualizations you created.
#
# As noted above, you can export the Notebook by clicking the **File** dropdown above, selecting **Export File As** and then selecting **HTML** as shown here:
# <div>
# <img src="https://github.com/HigherEdData/Du-Bois-STEM/blob/main/readings-images/htmlexport.jpg?raw=true" width="500" />
# </div>

# %% [markdown]
# # More Resources and References
#
# Github Repository for the #DuboisChallenge2024
# https://github.com/ajstarks/dubois-data-portraits/blob/master/challenge/2024/README.md
#
# Du Bois Challenge 2024 Recap
# https://speakerdeck.com/ajstarks/du-bois-challenge-2024-recap
#
# 2024 Du Bois Challenge using R Programming.
# https://medium.com/illumination/2024-du-bois-challenge-using-r-programming-02af8afa5626
#
# Developing Du Bois’s Data Portraits with Python and Matplotlib
# https://www.edriessen.com/2024/02/07/developing-du-boiss-data-portraits-with-python-and-matplotlib/
#
# Three Tricks I Learned In The Du Bois Data Visualization Challenge
# https://nightingaledvs.com/recreating-historical-dataviz-three-tricks-i-learned-in-the-du-bois-data-visualization-challenge/
#
# Molly Kuhs Du Bois Challenge repo
# https://github.com/makuhs/DuboisChallenge
#
# #DuBoisChallenge2024 using Python and Matplotlib
# https://github.com/edriessen/dubois24-python-matplotlib
#
# #DuboisChallenge2024 using R
# https://github.com/sndaba/2024DuBoisChallengeInRstats/tree/main
#
# #DuboisChallenge2024 using Tableau
# https://public.tableau.com/app/profile/camaal.moten7357/vizzes
